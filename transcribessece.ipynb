# %% [markdown]
# <a href="https://colab.research.google.com/github/omprakash236/Eventm-Managemet/blob/main/transcribessece.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcome in google colab')
# Out:
# welcome in google colab
